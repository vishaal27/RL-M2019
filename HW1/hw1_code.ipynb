# %% [markdown]
# # Q1. Nonstationary Environment: Sample Average action-value method

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=500
epsilon=0.1
n_steps=10000

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    norm=np.random.normal(0, 1)
    for i in range(n_bandits):
        q_start_values.append(norm)
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        q_start_values+=np.random.normal(0, 0.01, n_bandits)

        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
        
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1)  #changed
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=(1/n_values[action_chosen])*(reward-q_values[action_chosen])

plot_rewards_sa=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_sa=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_rewards_sa)
plt.xlabel('steps')
plt.ylabel('average reward')
plt.show()

plt.figure(2)
plt.plot(plot_optimal_percentage_sa)
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.show()

# %% [markdown]
# # Q1. Nonstationary Environment: Constant step-size parameter action-value method

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=500
epsilon=0.1
n_steps=10000
step_size=0.1

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    norm=np.random.normal(0, 1)
    for i in range(n_bandits):
        q_start_values.append(norm)
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        q_start_values+=np.random.normal(0, 0.01, n_bandits)

        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=step_size*(reward-q_values[action_chosen])

plot_rewards_css=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_css=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_rewards_css, c='r')
plt.plot(plot_rewards_sa, c='b')
from matplotlib.lines import Line2D
custom_lines=[Line2D([0], [0], color='r', lw=4), Line2D([0], [0], color='b', lw=4)]
plt.xlabel('steps')
plt.ylabel('average reward')
plt.legend(custom_lines, ['constant step size', 'sample average'])
plt.show()

plt.figure(2)
plt.plot(plot_optimal_percentage_css, c='r')
plt.plot(plot_optimal_percentage_sa, c='b')
from matplotlib.lines import Line2D
custom_lines=[Line2D([0], [0], color='r', lw=4), Line2D([0], [0], color='b', lw=4)]
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.legend(custom_lines, ['constant step size', 'sample average'])
plt.show()

# %% [markdown]
# # Q2. Stationary Environment: Optimistic Estimate initialisation

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=2000
epsilon=0
n_steps=1000
step_size=0.1

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    for i in range(n_bandits):
        q_start_values.append(np.random.normal(0, 1, 1))
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=step_size*(reward-q_values[action_chosen])

plot_rewards_optimistic_stationary=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_optimistic_stationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_optimal_percentage_optimistic_stationary)
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.show()

# %% [markdown]
# # Q2. Stationary Environment: Epsilon Greedy

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=500
epsilon=0.1
n_steps=1000
step_size=0.1

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    for i in range(n_bandits):
        q_start_values.append(np.random.normal(0, 1, 1))
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=step_size*(reward-q_values[action_chosen])

plot_rewards_realistic_stationary=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_realistic_stationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_optimal_percentage_realistic_stationary, c='r')
plt.plot(plot_optimal_percentage_optimistic_stationary, c='b')
from matplotlib.lines import Line2D
custom_lines=[Line2D([0], [0], color='r', lw=4), Line2D([0], [0], color='b', lw=4)]
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.legend(custom_lines, ['optimistic estimate', 'epsilon greedy'])
plt.show()

# %% [markdown]
# # Q2. Nonstationary Environment: Optimistic estimate initialisation

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=2000
epsilon=0
n_steps=1000
step_size=0.1

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    norm=np.random.normal(0, 1)
    for i in range(n_bandits):
        q_start_values.append(norm)
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        q_start_values+=np.random.normal(0, 0.01, n_bandits)
        
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=step_size*(reward-q_values[action_chosen])

plot_rewards_optimisitic_non_stationary=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_optimistic_non_stationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_optimal_percentage_optimistic_non_stationary)
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.show()

# %% [markdown]
# # Q2. Nonstationary Environment: Epsilon Greedy

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=2000
epsilon=0.1
n_steps=1000
step_size=0.1

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    norm=np.random.normal(0, 1)
    for i in range(n_bandits):
        q_start_values.append(norm)
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        q_start_values+=np.random.normal(0, 0.01, n_bandits)
        
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=n_optimal_chosen/(i+1)
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=step_size*(reward-q_values[action_chosen])

plot_rewards_optimal_percentage_realistic_non_stationary=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_realistic_non_stationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_optimal_percentage_realistic_non_stationary, c='r')
plt.plot(plot_optimal_percentage_optimistic_non_stationary, c='b')
from matplotlib.lines import Line2D
custom_lines=[Line2D([0], [0], color='r', lw=4), Line2D([0], [0], color='b', lw=4)]
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.legend(custom_lines, ['optimistic estimate', 'epsilon greedy'])
plt.show()

# %% [markdown]
# # Q3. Nonstationary Environment: Unbiased constant step-size trick

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=2000
epsilon=0.1
n_steps=10000
step_size=0.1

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    o_n=0
    
    q_start_values=[]
    norm=np.random.normal(0, 1)
    for i in range(n_bandits):
        q_start_values.append(norm)
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        q_start_values+=np.random.normal(0, 0.01, n_bandits)
        o_n=o_n+step_size*(1-o_n)
        
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=(step_size/o_n)*(reward-q_values[action_chosen])

# plot_rewards_css=list(np.asarray(each_step_rewards)/n_runs)
plot_optimal_percentage_unbiased_non_stationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_optimal_percentage_unbiased_non_stationary)
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.show()

# %% [markdown]
# # Q4. Stationary Environment: UCB

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import math

n_runs=2000
epsilon=0.1
n_steps=1000
step_size=0.1
c_value=2

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    o_n=0
    
    q_start_values=[]
    for i in range(n_bandits):
        q_start_values.append(np.random.normal(0, 1, 1))
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            reg_array=[c_value*math.sqrt(math.log(i+1)/(n_values[ac]+1)) for ac in range(n_bandits)]
#             print(np.add(q_values, reg_array))
            action_chosen=np.argmax([sum(ite) for ite in zip(q_values, reg_array)])
            
#         print(action_chosen)
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=(1/n_values[action_chosen])*(reward-q_values[action_chosen])

plot_rewards_ucb_stationary=list(np.asarray(each_step_rewards)/n_runs)
plot_ucb_stationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_rewards_ucb_stationary, c='r')
plt.plot(plot_rewards_optimistic_stationary, c='g')
plt.plot(plot_rewards_realistic_stationary, c='b')
from matplotlib.lines import Line2D
custom_lines=[Line2D([0], [0], color='r', lw=4), Line2D([0], [0], color='b', lw=4), Line2D([0], [0], color='g', lw=4)]
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.legend(custom_lines, ['UCB', 'epsilon greedy', 'optimistic estimate'])
plt.show()

# %% [markdown]
# # Q4. Nonstationary Environment: UCB

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import math

n_runs=2000
epsilon=0.1
n_steps=1000
step_size=0.1
c_value=2

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[0]*n_steps

for run_no in range(n_runs):
    print('Run number: '+str(run_no))
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    o_n=0
    
    q_start_values=[]
    norm=np.random.normal(0, 1)
    for i in range(n_bandits):
        q_start_values.append(norm)
        
    
    n_optimal_chosen=0
    
    for i in range(n_steps):
        
        q_start_values+=np.random.normal(0, 0.01, n_bandits)
        
        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            reg_array=[c_value*math.sqrt(math.log(i+1)/(n_values[ac]+1)) for ac in range(n_bandits)]
            action_chosen=np.argmax([sum(ite) for ite in zip(q_values, reg_array)])

            
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            optimal_chosen_percentage_for_plot[i]+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        each_step_rewards[i]+=reward
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=(1/n_values[action_chosen])*(reward-q_values[action_chosen])

plot_rewards_ucb_nonstationary=list(np.asarray(each_step_rewards)/n_runs)
plot_ucb_nonstationary=list(np.asarray(optimal_chosen_percentage_for_plot)/n_runs)
# Out:
# Run number: 0
# Run number: 1
# Run number: 2
# Run number: 3
# Run number: 4
# Run number: 5
# Run number: 6
# Run number: 7
# Run number: 8
# Run number: 9
# Run number: 10
# Run number: 11
# Run number: 12
# Run number: 13
# Run number: 14
# Run number: 15
# Run number: 16
# Run number: 17
# Run number: 18
# Run number: 19
# Run number: 20
# Run number: 21
# Run number: 22
# Run number: 23
# Run number: 24
# Run number: 25
# Run number: 26
# Run number: 27
# Run number: 28
# Run number: 29
# Run number: 30
# Run number: 31
# Run number: 32
# Run number: 33
# Run number: 34
# Run number: 35
# Run number: 36
# Run number: 37
# Run number: 38
# Run number: 39
# Run number: 40
# Run number: 41
# Run number: 42
# Run number: 43
# Run number: 44
# Run number: 45
# Run number: 46
# Run number: 47
# Run number: 48
# Run number: 49
# Run number: 50
# Run number: 51
# Run number: 52
# Run number: 53
# Run number: 54
# Run number: 55
# Run number: 56
# Run number: 57
# Run number: 58
# ...

# %%
plt.figure(1)
plt.plot(plot_rewards_ucb_nonstationary, c='r')
plt.plot(plot_rewards_optimistic_non_stationary, c='g')
plt.plot(plot_rewards_realistic_non_stationary, c='b')
from matplotlib.lines import Line2D
custom_lines=[Line2D([0], [0], color='r', lw=4), Line2D([0], [0], color='b', lw=4), Line2D([0], [0], color='g', lw=4)]
plt.xlabel('steps')
plt.ylabel('% optimal action')
plt.legend(custom_lines, ['UCB', 'epsilon greedy', 'optimistic estimate'])
plt.show()
