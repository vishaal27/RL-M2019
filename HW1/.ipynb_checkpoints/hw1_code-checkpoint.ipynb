# %%
import numpy as np
import random
import matplotlib.pyplot as plt

n_runs=1
epsilon=0.1
n_steps=10000

each_step_rewards=[0]*n_steps
optimal_chosen_percentage_for_plot=[]

for i in range(n_runs):
    n_bandits=10
    q_values=[0]*n_bandits
    n_values=[0]*n_bandits
    
    q_start_values=[]
    for i in range(n_bandits):
        q_start_values.append(np.random.normal(0, 1, 1))
        
    n_optimal_chosen=0
    rewards=[]
    
    for i in range(n_steps):
        for i in range(n_bandits):
            q_start_values[i]+=np.random.normal(0, 0.01, 1)

        prob=random.random()
        if(prob<epsilon):
            action_chosen=random.randint(0, n_bandits-1)
        else:
            action_chosen=np.argmax(q_values)
        
        optimal_action=np.argmax(q_start_values)
        if(optimal_action==action_chosen):
            n_optimal_chosen+=1
            
        reward=np.random.normal(q_start_values[action_chosen], 1, 1)
        rewards.append(reward)
        
        n_values[action_chosen]+=1
        q_values[action_chosen]+=(1/n_values[action_chosen])*(reward-q_values[action_chosen])

    rewards_for_plot.append(np.mean(rewards))
    optim
        
plt.figure(1)
plt.plot(rewards)
plt.show()

print(n_optimal_chosen)

plt.figure(2)
plt.plot(n_optimal_chosen)
plt.show()
# Out:
# 5254
